# %%
# Run once with real value then revert.
KEY = '<redacted>'

# %%
# Common imports, constants and functionality.

import datetime
import itertools
import json
import requests
import time

V1_BASE = 'https://api.torn.com'
V2_BASE = f'{V1_BASE}/v2'

class Missing:
    def _propagate(self):
        return self

    def __getattr__(self, name):
        return self._propagate
    
    def __bool__(self):
        return False


class Jsh:
    @classmethod
    def wrap(cls, inner):
        return Jsh(inner) if Jsh.wrappable(inner) else inner
    
    @classmethod
    def wrappable(cls, inner):
        return inner.__class__.__name__ == 'dict'
    
    @classmethod
    def fetch(cls, url):
        res = requests.get(url)
        if not res.ok:
            raise(RuntimeError(f'Failed to fetch "{url}": {res.error}'))
        data = json.loads(res.content)
        if 'error' in data:
            raise(RuntimeError(f'Error returned from "{url}": {data["error"]}'))
        return Jsh(data)
    
    def __init__(self, inner):
        assert(Jsh.wrappable(inner))
        self._inner = inner

    def __getattr__(self, name):
        if name == '_inner':
            return self._inner
        if not name in self._inner:
            return Missing()
        v = self._inner[name]
        match v.__class__.__name__:
            case 'dict': return Jsh(v)
            case 'list': return [Jsh.wrap(item) for item in v]
            case _: return v
    
    def __repr__(self):
        return str(self._inner)
    
    def has(self, name):
        return name in self._inner
    
    def getraw(self, name):
        return self._inner[name]
    
    def dumps(self):
        return json.dumps(self._inner, indent=2)

# %%
url = f'{V2_BASE}/racing/tracks?key={KEY}'
tracks = {}

try:
    jsh = Jsh.fetch(url)
except Exception as e:
    print(f'Failed to fetch "{url}": {e}')
    exit(1)
if not jsh.has('tracks'):
    print(f'No "tracks" in:\n{jsh.dumps()}')
    exit(1)
tracks.update([(track.id, track.title) for track in jsh.tracks])

print(f'Found {len(tracks)} tracks(s):')
for (id, name) in tracks.items():
    print(f'{name} [{id}]')
# Out:
# Found 16 tracks(s):
# Uptown [6]
# Withdrawal [7]
# Underdog [8]
# Parkland [9]
# Docks [10]
# Commerce [11]
# Two Islands [12]
# Industrial [15]
# Vector [16]
# Mudpit [17]
# Hammerhead [18]
# Sewage [19]
# Meltdown [20]
# Speedway [21]
# Stone Park [23]
# Convict [24]

# %%
url = f'{V2_BASE}/racing/carupgrades?key={KEY}'

try:
    jsh = Jsh.fetch(url)
except Exception as e:
    print(f'Failed to fetch "{url}": {e}')
    exit(1)
if not jsh.has('carupgrades'):
    print(f'No "carupgrades" in:\n{jsh.dumps()}')
    exit(1)

print('id,name,description,category,subcategory,class_required,points,money,top_speed,acceleration,braking,handling,safety,dirt,tarmac')
for u in jsh.carupgrades:
    print(f'{u.id},{u.name},"{u.description}",{u.category},{u.subcategory},{u.class_required},{u.cost.points},{u.cost.cash},{u.effects.top_speed},{u.effects.acceleration},{u.effects.braking},'
          f'{u.effects.handling},{u.effects.safety},{u.effects.dirt},{u.effects.tarmac}')
# Out:
# id,name,description,category,subcategory,class_required,points,money,top_speed,acceleration,braking,handling,safety,dirt,tarmac
# 1,Strip Out,"By removing all of the unnecessary interior from the car you can increase the power to weight ratio, therefore increasing speed and acceleration. The car will also handle better and brake quicker as there is less mass to maneuver and stop.",Weight Reduction,Strip out,E,1,0,1,1,1,1,0,0,0
# 4,Uprated Springs (Soft),"These replace the original springs and allow for improved handling off road.",Suspension,Springs,E,2,3500,0,0,0,1,0,1,-1
# 5,Uprated Springs (Medium),"These replace the original springs and allow for slightly improved handling on all surfaces.",Suspension,Springs,E,2,3500,0,0,0,1,0,0,0
# 6,Uprated Springs (Hard),"These replace the original springs and allow for improved handling on a track.",Suspension,Springs,E,2,3500,0,0,0,1,0,-1,1
# 9,Uprated Brake Pads,"These pads will allow you to brake slightly later due to greater friction properties than their standard counterparts.",Brakes,Pads,E,2,1500,0,0,1,0,0,0,0
# 11,Back Box,"This back box will allow a slightly improved air flow allowing exhaust gases to expelled fractionally quicker allowing for small increases in acceleration and top speed.",Exhaust and Induction,Exhaust,E,2,3000,1,1,0,0,0,0,0
# 12,Uprated Air Filter Element,"This air filter element replaces the standard part for increased airflow to the engine.",Exhaust and Induction,Air Filter,E,2,3000,1,1,0,0,0,0,0
# 15,Quick Shift,"This part allows for shorter gear changes, crucial for acceleration.",Transmission,Shifting,E,2,2500,0,1,0,0,0,0,0
# 2,Race Overalls,"These overalls will protect you in the result of a fire.",Safety,Overalls,E,3,5000,0,0,0,0,1,0,0
# 3,Helmet,"This Helmet will protect you if you are unfortunate enough to have an accident.",Safety,Helmet,E,3,7500,0,0,0,0,1,0,0
# 7,Budget Upgrade Tires,"These tires will allow for better grip compared to standard factory fit tires.",Wheels and Tyres,Tyres,E,3,6500,0,1,1,1,0,0,0
# 8,Steel Rims,"These steel rims are lightweight replacements that will increase the cars handling.",Wheels and Tyres,Wheels,E,3,6000,0,0,0,1,0,0,0
# 10,Uprated Brake Discs,"These discs will allow you to brake slightly later with their greater stopping power than their standard counterparts.",Brakes,Discs,E,3,5500,0,0,1,0,0,0,0
# 13,Uprated Gaskets,"These gaskets are essential when putting more power through an engine for solid seals between your new high performance parts.",Engine,Gasket,E,3,6000,0,0,0,0,1,0,0
# 14,Ported and Polished Head,"This creates less friction within inlet and outlet valves increasing efficiency and ultimately power.",Engine,Engine Porting,E,3,6000,1,1,0,0,0,0,0
# 16,Fixed Rear Spoiler,"This allows a set rate of down-force creating increased handling and top end stability.",Aerodynamics,Spoiler,E,3,5500,1,0,0,1,0,0,0
# 17,Racing Steering Wheel,"This steering wheel is lighter than its original counterpart, it will increase handling with its improved grip for the driver.",Weight Reduction,Steering wheel,D,4,1200,0,0,0,1,0,0,0
# 19,Fire Extinguisher,"In the case of a fire this will greatly improve your chances of survival.",Safety,Fire Extinguisher,D,4,4000,0,0,0,0,1,0,0
# 25,Polyurethane Bushings Front,"These are an essential upgrade from original rubber counterparts as they are harder wearing and also stiffen up the cars handling properties. This set is for the front end of the car.",Suspension,Front Bushes,D,4,5000,0,0,0,1,0,0,0
# 26,Polyurethane Bushings Rear,"These are an essential upgrade from original rubber counterparts as they are harder wearing and also stiffen up the cars handling properties. This set is for the rear end of the car.",Suspension,Rear Bushes,D,4,5000,0,0,0,1,0,0,0
# 30,Grooved Brake Discs,"These replace the uprated brake discs and have grooves around them allowing for greater cooling, this enables even later braking into corners as the brakes do not overheat so easily.",Brakes,Discs,D,4,14000,0,0,2,0,0,0,0
# 31,Fast Road Brake Fluid,"This item is able to cope with higher temperatures than standard brake fluid and will improve your braking consistency over a race period.",Brakes,Fluid,D,4,4000,0,0,1,0,0,0,0
# 35,Polished Throttle Body,"This part has much less friction than its standard counterpart enabling quicker, more efficient fuel delivery.",Engine,Engine Cleaning,D,4,5000,2,2,0,0,0,0,0
# 37,4 Pin Differential,"This part allows you to transfer all that precious power you have been creating onto the track without causing a big plume of smoke, a differential will vastly improve your acceleration by adjusting the power to the wheels preventing wheel spin.",Transmission,Differential,D,4,25000,0,1,0,1,0,0,0
# 39,Fast Road Clutch,"A standard manufacturer clutch will burn out in a matter of minutes with any high levels of power. To prevent any slipping and ensuring full traction off the line, an upgraded clutch is essential.",Transmission,Clutch,D,4,7000,0,1,0,0,0,0,0
# 18,Lightweight Flocked Dash,"By removing all unnecessary dash ancillaries you can make the car a lot lighter, flocking prevents sunlight reflection and also looks the part.",Weight Reduction,Interior,D,6,15000,0,2,0,0,0,0,0
# 20,Hans Device,"The Head And Neck Support device was created to reduce the likelihood of neck injuries in accidents, in many race series the use of this device is compulsory.",Safety,Safety Accessory,D,6,20000,0,0,0,0,1,0,0
# 21,Roll Cage,"In the incident of rolling your motor vehicle having a roll cage is highly beneficial and is compulsory in ALL motorsport series in some shape or form.",Safety,Roll cage,D,6,19000,0,0,0,0,2,0,0
# 22,Uprated  Springs & Dampers (Soft),"These replace uprated springs and as a set include uprated dampers allowing for greater handling, as before the soft springs allow for greater handling off road.",Suspension,Springs,D,6,12000,0,0,0,2,0,1,-1
# 23,Uprated Springs & Dampers (Med),"These replace uprated springs and as a set include uprated dampers allowing for greater handling, as before the medium springs allow for greater all round handling rather than a specialist surface.",Suspension,Springs,D,6,12000,0,0,0,2,0,0,0
# 24,Uprated Springs & Dampers (Hard),"These replace uprated springs and as a set include uprated dampers allowing for greater handling, as before the hard springs allow for greater handling on a track.",Suspension,Springs,D,6,12000,0,0,0,2,0,-1,1
# 27,Fast Road Tires,"These tires replace the budget upgrades and will furthermore improve the cars handling abilities.",Wheels and Tyres,Tyres,D,6,17000,0,2,2,2,0,0,0
# 28,Lightweight Alloys,"These are even lighter than steel rims and will further improve handling.",Wheels and Tyres,Wheels,D,6,20000,0,0,0,2,0,0,0
# 29,Fast Road Brake Pads,"These replace the uprated brake pads and allow for even later braking into corners.",Brakes,Pads,D,6,20000,0,0,2,0,0,0,0
# 32,Cat-Back Exhaust,"Replacing an upgraded back box, this cat-back system will expel unwanted exhaust gases more quickly allowing for greater power from the engine.",Exhaust and Induction,Exhaust,D,6,12000,2,2,0,0,0,0,0
# 33,Open Air Filter,"Totally replacing the standard car air-box and replacing it with an open air filter will allow the car to breathe more freely creating throttle response and power increases.",Exhaust and Induction,Air Filter,D,6,8000,2,2,0,0,0,0,0
# 34,Fast Road Fuel Pump,"This gets the all important fuel to the engine quicker and thus improves the engines power by meeting the engines high fuel demands at top revs.",Engine,Fuel Pump,D,6,7000,1,1,0,0,0,0,0
# 36,Fast Road Camshaft,"This part adjusts the timing of an engine as manufacturers insert cams suitable for a mixture of economy and performance as standard, fuel economy is not an issue that many race enthusiasts are worried about, so get more power from these fast road cams.",Engine,Camshaft,D,6,9000,2,1,0,0,0,0,0
# 38,Lightened Standard Flywheel,"This part allows the engine to rev more quickly and freely reaching gear changes in no time.",Transmission,Flywheel,D,6,8000,0,1,0,0,0,0,0
# 55,Stage One Turbo kit,"This stage one kit converts your car into a turbocharged monster. By increasing the density of air entering the engine a lot more power is generated, even from small capacity engines.",Engine,Turbo,C,12,40000,4,4,0,0,0,0,0
# 41,Emergency Power Cut-off Switch,"An essential item when racing, this switch disables the battery in the event of an accident to reduce the likelihood of unwanted fuel ignition.",Safety,Cut-off,C,2,2000,0,0,0,0,1,0,0
# 52,Air filter Cold Air Feed,"This part adds to an air filter by providing it with a direct supply of fresh air for improved engine induction, in turn creating more power and improved throttle response.",Aerodynamics,Engine Cooling,C,2,3000,1,0,0,0,0,0,0
# 43,Upper Front Strut Brace,"This item stiffens up the front of the car allowing sharper handling.",Suspension,Upper Front Brace,C,4,6000,0,0,0,1,0,0,0
# 44,Lower Front Strut Brace,"This item stiffens up the front suspension of the car allowing for more precise handling.",Suspension,Lower Front Brace,C,4,6000,0,0,0,1,0,0,0
# 45,Rear Strut Brace,"This item stiffens up the rear of the car allowing sharper handling.",Suspension,Rear Brace,C,4,6000,0,0,0,1,0,0,0
# 50,Braided Brake Hoses,"These hoses do not expand under braking when hot and thus allow a consistent resistance, essential when timing those last minute braking points.",Brakes,Brake Accessory,C,4,6000,0,0,1,0,0,0,0
# 64,Air Forced Engine Cooling,"Keeping engine temperatures down will not only increase reliability, but air induction temperatures will also be lower which increases power output.",Aerodynamics,Engine Cooling,C,4,6000,2,0,0,0,0,0,0
# 40,Polycarbonate Windows,"This upgrade will lighten the car even more for an increased power to weight ratio.",Weight Reduction,Windows,C,6,9000,1,1,0,0,0,0,0
# 42,Bucket seat and 3 Point Harness,"This butt hugging seat and 3 point harness will hold you in during tight turns and hard acceleration.",Safety,Seat,C,6,17000,0,0,0,0,2,0,0
# 46,Track Tires,"These tires replace the fast road tires and are illegal for road use as they are completely tread-less or 'slick'; they give endless grip on a dry track.",Wheels and Tyres,Tyres,C,6,20000,0,3,3,3,0,-1,1
# 47,Rally Tires,"These tires replace the fast road tires and are illegal for road use as they have dirt gripping nodules all over them providing unbelievable grip on a loose dirt surface.",Wheels and Tyres,Tyres,C,6,20000,0,3,3,3,0,1,-1
# 48,Grooved and Drilled Brake Discs,"Replacing the grooved brake discs, these are both drilled and grooved allowing for even better cooling and as a result later braking is achievable.",Brakes,Discs,C,6,17000,0,0,4,0,0,0,0
# 49,Competition Racing Brake Pads,"These pads replace fast road pads and have higher tolerances to heat allowing for more consistent braking throughout a race with less fade during the penultimate stages.",Brakes,Pads,C,6,7000,0,0,3,0,0,0,0
# 51,Brake Balance Bias Control,"This item is perfect for the advanced precision driver who wishes to adjust their braking bias (front to rear balance) for that perfect corner entry.",Brakes,Brake Control,C,6,9000,0,0,1,0,0,0,0
# 53,Full Exhaust System,"This system replaces the cat-back system and provides a free-flowing, larger bore exhaust pipe from after the manifold to the back box eliminating the catalytic converter. Increases in power and acceleration are certain.",Exhaust and Induction,Exhaust,C,6,25000,3,3,0,0,0,0,0
# 54,Uprated Forged Pistons,"Before adding a turbo-charger it is essential to use forged alloy pistons for higher pressure and temperature tolerances so you do not compromise reliability, these particular pistons also increase compression rates providing more power.",Engine,Pistons,C,6,20000,2,2,0,0,0,0,0
# 56,Stage One Remap,"When drastically changing components of an engine (such as a turbocharger) it is essential to get the car remapped for safe running and more importantly to achieve peak performance.",Engine,Computer,C,6,20000,1,1,0,0,0,0,0
# 57,Competition Racing Fuel Pump,"To keep up with the engines vast demand for fuel, a larger more powerful fuel pump must replace the fast road fuel pump to enable maximum performance.",Engine,Fuel Pump,C,6,9000,2,2,0,0,0,0,0
# 58,Competition Polished Throttle Body,"This part creates less friction for an increase in power greater than the normal polished throttle body as it has a larger bore with precision polished internals for surprisingly high power increases.",Engine,Engine Cleaning,C,6,8000,3,3,0,0,0,0,0
# 61,Competition Racing Clutch,"With increased power, even a fast road clutch will burn out in a matter of minutes to prevent any slipping and to ensure full traction off the line, a competition ceramic clutch is essential.",Transmission,Clutch,C,6,9000,0,2,0,0,0,0,0
# 62,Ultra-Light Flywheel,"Replacing the lightened standard flywheel, this part allows the engine to rev even more freely with the car picking up out of the corners outstandingly.",Transmission,Flywheel,C,6,12000,1,3,0,0,0,0,0
# 63,Air Cooling Ducts for Brakes,"This item will keep brake temperatures low which is essential as you will lose all braking abilities if they overheat.",Aerodynamics,Brake Cooling,C,6,12000,0,0,1,2,0,0,0
# 65,Premium Uprated Fuel,"This higher octane fuel will burn more vigorously under compression and ignition creating more power.",Fuel,Fuel,C,6,9000,1,1,0,0,0,0,0
# 59,Straight Cut Gearbox (Long Ratio),"Straight cut gear boxes can handle vast amounts of power, this long geared box is perfect for those lengthy straights as it allows for a high top end speed.",Transmission,Gearbox,C,8,25000,3,2,0,0,0,0,0
# 60,Straight Cut Gearbox (Short Ratio),"Straight cut gear boxes can handle vast amounts of power, this short geared box is perfect for those tight and twisty tracks as it allows for rapid acceleration.",Transmission,Gearbox,C,8,25000,2,3,0,0,0,0,0
# 84,Paddle Shift Gearbox (Long Ratio),"This track suited gearbox replaces the straight cut box as the best money can buy, this particular item is fitted with longer gear ratios for top end speed.",Transmission,Gearbox,B,10,40000,4,3,0,0,0,-2,2
# 85,Paddle Shift Gearbox (Short Ratio),"This track suited gearbox replaces the straight cut box as the best money can buy, this particular item is fitted with shorter gear ratios for acceleration.",Transmission,Gearbox,B,10,40000,3,4,0,0,0,-2,2
# 86,Rally Gearbox (Long Ratio),"This rally suited gearbox replaces the straight cut box as the best money can buy, this particular item is fitted with longer gear ratios for top end speed.",Transmission,Gearbox,B,10,40000,4,3,0,0,0,2,-2
# 87,Rally Gearbox (Short Ratio),"This rally suited gearbox replaces the straight cut box as the best money can buy, this particular item is fitted with shorter gear ratios for acceleration.",Transmission,Gearbox,B,10,40000,3,4,0,0,0,2,-2
# 81,Stage Two Turbo kit,"This bigger turbo replaces the stage one turbo as it is capable of running at a higher pressure creating more glorious boost.",Engine,Turbo,B,12,50000,5,5,0,0,0,0,0
# 71,Front Adjustable Tie Rods,"This item helps you tune the toe and camber on the front of the car to perfect its handling.",Suspension,Front Tie Rods,B,4,5000,0,0,0,1,0,0,0
# 72,Adjustable Rear Control arms,"This item helps you tune the rear of the car to perfect its handling.",Suspension,Rear Control Arms,B,4,5000,0,0,0,1,0,0,0
# 66,Carbon Fiber Roof,"This item lightens the car significantly to increase the cars power to weight ratio.",Weight Reduction,Roof,B,6,12000,1,1,0,0,0,0,0
# 67,Carbon Fiber Trunk,"This item lightens the car significantly to increase the cars power to weight ratio.",Weight Reduction,Boot,B,6,17000,1,1,0,0,0,0,0
# 68,Race Overalls FIA Approved,"These overalls will protect you from burns in the result of a fire and are FIA approved so meet a high standard suitable for competitive racing.",Safety,Overalls,B,6,15000,0,0,0,0,2,0,0
# 69,Helmet FIA Approved,"This Helmet will protect you if you are unfortunate enough to have an accident and is FIA approved so meets a high standard which is suitable for competitive racing.",Safety,Helmet,B,6,18000,0,0,0,0,2,0,0
# 70,Fire Extinguisher FIA Approved,"In case of a fire this will greatly improve your chances of survival and is FIA approved so meets a high standard which is suitable for competitive racing.",Safety,Fire Extinguisher,B,6,18000,0,0,0,0,2,0,0
# 76,Rally-Cross Tires,"These tires are the perfect compromise between rally and track tires, they are not an essential upgrade but prevent the likelihood of a severe handicap if tires are used on the wrong track.",Wheels and Tyres,Tyres,B,6,20000,0,3,3,3,0,0,0
# 78,Stainless Steel 4-1 Manifold,"Between the engine block to the full exhaust system, this manifold releases the engines full potential by expelling the exhaust gases in the most efficient way possible drastically improving the cars power.",Exhaust and Induction,Manifold,B,6,15000,3,1,0,0,0,0,0
# 79,Forced Induction Kit,"Replacing an open air filter, this forced induction kit is an enclosed unit with air being forced directly through the filter and subsequently into the engine. Throttle response is vastly improved with this item.",Exhaust and Induction,Air Filter,B,6,10000,3,3,0,0,0,0,0
# 80,Bored Out Engine + Forged Pistons,"Boring out the engine for a larger capacity and replacing the upgraded forged pistons for those of a larger size creates monumental power gains effecting both acceleration and top speed.",Engine,Pistons,B,6,30000,4,4,0,0,0,0,0
# 83,Front Mounted Intercooler,"With higher levels of turbo boost it is essential to keep engine temperatures down to prevent overheating, turbochargers also work better with cooler temperatures (both ambient and internal).",Engine,Intercooler,B,6,15000,2,1,0,0,1,0,0
# 88,Adjustable Rear Spoiler,"Replacing the fixed rate spoiler, this spoiler allows for greater or lesser down-force as required per track allowing for more effective results.",Aerodynamics,Spoiler,B,6,20000,2,1,0,2,0,0,0
# 89,Super Octane Fuel,"An even higher grade of fuel than premium octane, super octane will burn even more vigorously under compression and ignition creating yet more power.",Fuel,Fuel,B,6,13000,2,2,0,0,-1,0,0
# 73,Coil-over Suspension (Soft),"Coil-over suspension replaces uprated springs and dampers as one unit and provides a more precise handling response, this unit is soft and more suited to off road.",Suspension,Springs,B,8,25000,0,0,0,4,0,2,-2
# 74,Coil-over Suspension (Medium),"Coil-over suspension replaces uprated springs and dampers as one unit and provide a more precise handling response, this unit is a good all round set-up.",Suspension,Springs,B,8,25000,0,0,0,4,0,0,0
# 75,Coil-over Suspension (Hard),"Coil-over suspension replaces uprated springs and dampers as one unit and provides a more precise handling response, this unit is hard and more suited to the track.",Suspension,Springs,B,8,25000,0,0,0,4,0,-2,2
# 77,4 Pot Uprated Brakes,"These brakes consist of four pistons per caliper allowing for some serious stopping power.",Brakes,Callipers,B,8,27000,0,0,4,0,0,0,0
# 82,Stage Two Remap,"In order for the new turbo to function most effectively a stage two remap will increase the turbo boost and set the engine up taking this upgrade into account.",Engine,Computer,B,8,30000,2,2,0,0,0,0,0
# 96,6 Pot Uprated Brakes,"Replacing the already spectacular 4-pot brakes, these 6-pots are similar to those used on all formula one cars. Each piston consists of 6 brake pots generating an astonishing braking force unrivalled by other similar items.",Brakes,Callipers,A,10,30000,0,0,5,0,0,0,0
# 100,Stage Three Remap,"In order for the new turbo to function most effectively a stage three remap will increase the turbo boost and set the engine up taking this upgrade into account.",Engine,Computer,A,10,35000,3,3,0,0,0,0,0
# 99,Stage Three Turbo Kit,"This gigantic 360 degree ball-bearing turbo replaces the stage two turbo by running at an even higher pressure with fractional resistance, although there is a great amount of turbo lag the top end benefits are astronomical.",Engine,Turbo,A,18,60000,7,4,0,0,0,0,0
# 90,Carbon Fiber Hood,"This item further increases the cars power to weight ratio.",Weight Reduction,Hood,A,6,10000,1,1,0,0,0,0,0
# 97,Custom Forced Induction Kit,"Made specifically for each individual cars intake needs, this custom kit is far superior to an already highly effective forced induction kit.",Exhaust and Induction,Air Filter,A,6,15000,4,4,0,0,0,0,0
# 98,Competition Racing Camshaft,"Although these cams will make your car almost un-drivable at low speeds and produce sounds similar to that of a tractor, when at full grunt these cams produce absolute perfection in piston timing producing immense performance improvements.",Engine,Camshaft,A,6,12000,3,2,0,0,0,0,0
# 103,Super Octane Fuel Plus Nitrous,"All the benefits of super octane fuel plus direct injection of nitrous into your engine for copious amount of power at the touch of a button.",Fuel,Fuel,A,6,17000,5,5,0,0,-5,0,0
# 91,Full Roll Cage FIA Approved,"This competition standard roll cage will give you maximum protection in the event of an accident.",Safety,Roll cage,A,8,25000,0,0,0,0,3,0,0
# 92,Bucket Seat and 6 Point Harness,"Replacing the 3 point harness, this competition approved harness and bucket seat combination offers maximum security. You'll go nowhere during those tight turns and under hard acceleration.",Safety,Seat,A,8,25000,0,0,0,0,3,0,0
# 93,Adjustable Coilover Suspension,"Replacing fixed rate coil-over suspension, these units can be adjusted depending on the track surface, condition and type offering flawless handling and great versatility (designed for track use).",Suspension,Springs,A,8,30000,0,0,0,5,0,-3,3
# 94,Group N Rally Suspension,"Replacing fixed rate coil-over suspension, these units can be adjusted depending on the rally surface, condition and type offering flawless handling and great versatility (designed for off road use).",Suspension,Springs,A,8,30000,0,0,0,5,0,3,-3
# 95,Ultra-Lightweight Alloys,"These alloys weigh in at a fraction of most racing alloys and allow for a superb cornering response.",Wheels and Tyres,Wheels,A,8,29000,0,0,0,3,0,0,0
# 101,Front Diffuser,"This item creates huge amounts of down force when fitted to the front underside of the car by reducing the air pressure below the vehicle. This item will improve every aspect of the car from handling to top end speed.",Aerodynamics,Front Diffuser,A,8,25000,2,2,0,2,0,0,0
# 102,Rear Diffuser,"This item creates huge amounts of down force when fitted to the rear underside of the car by reducing the air pressure below the vehicle. This item will improve every aspect of the car from handling to top end speed.",Aerodynamics,Rear Diffuser,A,8,25000,2,2,0,2,0,0,0

# %%
url = f'{V2_BASE}/faction/members?key={KEY}'
members = {}

try:
    jsh = Jsh.fetch(url)
except Exception as e:
    print(f'Failed to fetch "{url}": {e}')
    exit(1)
if not jsh.has('members'):
    print(f'No "members" in:\n{jsh.dumps()}')
    exit(1)
members.update([(member.id, member.name) for member in jsh.members])

print(f'Found {len(members)} members(s)')

for (id, name) in members.items():
    print(f'{name} [{id}]')
# Out:
# Found 30 members(s)
# Big_Tex1429 [1513734]
# Mingle [2122084]
# Talendrife [2143613]
# MaxamillionXX7 [2293468]
# Lexii [2637832]
# Pvpkiller [2682292]
# DukeSilver [2733982]
# Sofro [2734960]
# Socharis [2801249]
# AUSTINEZ [2843077]
# Rhysand [2919031]
# Kitana1988 [3037508]
# Popcorn- [3040244]
# Sniffles666 [3249261]
# Giftedbasicbee [3360473]
# Shodgson [3509557]
# VeronicaMars [3562079]
# Fikowi [3602025]
# Schwartzenadder [3623941]
# plexar [3646316]
# ChriSabi [3681518]
# SweetPetite [3713328]
# rsty [3743574]
# NTHRITE [3799007]
# Boduki [3825722]
# 000Machie000 [3829798]
# Djiinni [3871156]
# Parzival175 [3873916]
# Ahmad1Albustami [3894597]
# jordankk [3946191]

# %%
url = f'{V2_BASE}/racing/races?cat=custom&limit=100'
cutoff = datetime.datetime(2025, 11, 8, 0, 0, 0).timestamp()
remaining = 50
done = False

while url and not done:
    url += f'&key={KEY}'
    try:
        jsh = Jsh.fetch(url)
    except Exception as e:
        print(f'Failed to fetch "{url}": {e}')
        raise(e)
    if not jsh.has('races'):
        print(f'No "races" in:\n{jsh.dumps()}')
        raise(RuntimeError(f'No "races" in:\n{jsh.dumps()}'))
    for race in jsh.races:
        if race.schedule.start < cutoff:
          done = True
          break
        if race.status == 'in_progress' and race.track_id == 10: # Docks
            print(f'{race.id}: {race.title} @ {tracks[race.track_id]} ({race.status})')
            remaining -= 1
        if remaining < 1:
            done = True
            break
    url = jsh._metadata.links.prev
# Out:
# 17511890: Socks XP @ Docks (in_progress)
# 17512308: xprace @ Docks (in_progress)
# 17512445: bobbybob1694&#039;s race @ Docks (in_progress)
# 17512896: 1hr Start - Docks @ Docks (in_progress)
# 17512849: Matthew715&#039;s race @ Docks (in_progress)
# 17512815: DarkManV&#039;s race @ Docks (in_progress)
# 17512773: 1hr Start - Docks @ Docks (in_progress)
# 17512743: Hospitalize&#039;s race @ Docks (in_progress)
# 17512687: Santereas&#039;s race @ Docks (in_progress)
# 17512663: SisterChristian&#039;s race @ Docks (in_progress)
# 17512559: Ice_Addict&#039;s race @ Docks (in_progress)
# 17512318: Alba_Gu_Brath&#039;s race @ Docks (in_progress)
# 17512434: 1hr Start - Docks @ Docks (in_progress)
# 17512451: kurapylly&#039;s race @ Docks (in_progress)
# 17512384: mozgurl80&#039;s race @ Docks (in_progress)
# 17512366: Mnixos&#039;s race @ Docks (in_progress)
# 17511810: Letcherinium&#039;s race @ Docks (in_progress)
# 17512355: Buffalo_Bill&#039;s race @ Docks (in_progress)
# 17512280: Docks 100l @ Docks (in_progress)
# 17512247: 100 Laps Docks @ Docks (in_progress)
# 17512197: Docks Practice 100x Laps @ Docks (in_progress)
# 17511701: sharx&#039;s race @ Docks (in_progress)
# 17511974: Docks @ Docks (in_progress)
# 17512148: 1hr Start - Docks @ Docks (in_progress)
# 17510181: Trident Sunday Cup Racing  @ Docks (in_progress)
# 17512080: and08&#039;s race @ Docks (in_progress)
# 17512035: 1hr Start - Docks @ Docks (in_progress)
# 17511804: Docks @ Docks (in_progress)
# 17512011: 1hr Start - Docks @ Docks (in_progress)
# 17512001: 15m Start - Docks @ Docks (in_progress)
# 17511985: Dede&#039;s race @ Docks (in_progress)
# 17511959: docks 100 exp @ Docks (in_progress)
# 17511926: Teslana&#039;s race @ Docks (in_progress)
# 17511644: Pinball&#039;s race @ Docks (in_progress)
# 17511763: 1hr Start - Docks @ Docks (in_progress)
# 17511710: XP - Docks @ Docks (in_progress)
# 17511637: Docks XP @ Docks (in_progress)
# 17511179: FractalPariah&#039;s race @ Docks (in_progress)
# 17511530: Bellico&#39;s race @ Docks (in_progress)
# 17504013: Final Tally @ Docks (in_progress)
# 17511520: DJStone&#039;s race @ Docks (in_progress)
# 17511502: Santouryuu&#039;s race @ Docks (in_progress)
# 17511463: xp&#039;s race @ Docks (in_progress)
# 17510564: DejavuDocks @ Docks (in_progress)
# 17510242: DontTrip&#039;s race @ Docks (in_progress)
# 17511341: vincentys&#039;s race @ Docks (in_progress)
# 17511297: Long drives @ Docks (in_progress)
# 17511050: RS  @ Docks (in_progress)
# 17510942: RZHT Quick start XP Docks @ Docks (in_progress)
# 17510696: 1hr Start - Docks @ Docks (in_progress)

# %%
rids = [16894378, 16981530, 17057677, 17134189, 17282712, 17351216, 17426344, 17500628]
n = len(rids)
hdrs1 = list(itertools.repeat("", 2*n+1))
hdrs2 = ["name"]
for i in range(0, n):
    hdrs2.extend(["pos", "time"])
results = dict(
    (id, list(itertools.chain([name], itertools.repeat("", 2*len(rids)))))
    for (id, name) in members.items()
)
for i, rid in enumerate(rids):
    url = f'{V2_BASE}/racing/{rid}/race?key={KEY}'
    try:
        jsh = Jsh.fetch(url)
    except Exception as e:
        print(f'Failed to fetch "{url}": {e}')
        exit(1)
    if not jsh.has('race'):
        print(f'No "race" in:\n{jsh.dumps()}')
        exit(1)
    hdrs1[2*i+1] = tracks[jsh.race.track_id]
    for res in jsh.race.results:
        if res.driver_id in members:
            results[res.driver_id][2*i+1:2*i+3] = [
                str(res.position or ""),
                "DNF" if res.has_crashed else str(res.race_time or ""),
            ]

print(','.join(hdrs1))
print(','.join(hdrs2))
for res in results.values():
    print(','.join(res))
# Out:
# ,Two Islands,,Stone Park,,Industrial,,Hammerhead,,Underdog,,Mudpit,,Withdrawal,,Docks,
# name,pos,time,pos,time,pos,time,pos,time,pos,time,pos,time,pos,time,pos,time
# Big_Tex1429,9,12201.91,10,8552.09,3,8539.91,10,6856.58,,,,,3,12555.92,4,17882.53
# Mingle,2,10975.75,2,7988.65,1,8509.96,2,6117.43,2,9443.78,2,3964.55,,,3,17855.48
# Talendrife,,,,,,,,,,,,,,,,
# MaxamillionXX7,,,,,,,,,,,,,,,,
# Lexii,3,11070.75,4,8046.13,6,8658.94,8,6806.63,3,9479.06,3,3966.66,2,12546.7,1,17801.2
# Pvpkiller,13,25738.68,16,18027.42,14,14050.49,17,12512.64,14,15996.58,,,10,21377.13,,
# DukeSilver,6,11683.71,9,8407.59,5,8632.41,,,6,9511.47,11,6203.86,6,12694.51,7,17998.81
# Sofro,14,26635.15,14,14926.47,13,13901.66,16,11663.99,13,15719.78,13,11353.49,9,18990.89,9,26516.01
# Socharis,1,10961.4,1,7962.49,4,8558.44,1,6082.04,,,,,1,12477.77,,
# AUSTINEZ,,,,,,,15,9853.12,,,,,,,,
# Rhysand,,,,,,,,,,,,,,,,
# Kitana1988,,,5,8307.52,,,4,6259.57,7,9523.39,5,4006.9,,,6,17998.46
# Popcorn-,,,,,,,,,,,,,,,,
# Sniffles666,,,,,,,,,,,,,,,,
# Giftedbasicbee,,,,,,,,,,,,,,,,
# Shodgson,,,,,,,,,,,,,,,,
# VeronicaMars,,,,,,,,,,,,,,,,
# Fikowi,12,14208.8,13,10369.99,11,10390.56,12,7940.88,10,11575.61,12,7467.07,,,,
# Schwartzenadder,5,11500.62,8,8393.61,,,5,6291.12,4,9480.66,4,3978.86,4,12601.91,,
# plexar,,,,,,,,,,,,,,,,
# ChriSabi,,,,,,,,,1,9423.94,,,,,,
# SweetPetite,4,11330.57,3,8002.56,2,8526.25,3,6256.27,5,9492.26,1,3953.86,,,2,17832.12
# rsty,,,,,,,19,15562.95,12,14603.36,,,,,,
# NTHRITE,,,,,,,,,,,,,,,,
# Boduki,10,12417.97,11,8736.23,8,9019.58,9,6810.12,,,9,6020.92,5,12677.45,5,17995.71
# 000Machie000,11,13312.36,12,9665.84,10,9848.43,11,7396.04,8,9850.72,10,6081.77,,,,
# Djiinni,7,11829.58,7,8388.06,7,8826.8,7,6566.29,,,8,5645.3,7,12824.12,,
# Parzival175,,,15,15616.89,12,12453.77,14,9342.92,11,12660.33,7,4759.13,,,,
# Ahmad1Albustami,8,11963.35,6,8316.15,9,9132.87,6,6304.07,9,10059.35,6,4020.11,8,13391.71,8,19045.5
# jordankk,,,,,,,18,15542.63,,,14,23991.26,11,24387.29,,

# %%
url = f'{V2_BASE}/faction/chains?limit=100&sort=DESC'
cutoff = datetime.datetime(2025, 10, 24, 0, 0, 0)
chains = []

while url:
    url += f'&key={KEY}'
    try:
        jsh = Jsh.fetch(url)
    except Exception as e:
        print(f'Failed to fetch "{url}": {e}')
        exit(1)
    if not jsh.has('chains'):
        print(f'No "chains" in:\n{jsh.dumps()}')
        exit(1)
    chains += jsh.chains
    url = jsh._metadata.links.prev

print(f'Found {len(chains)} chain(s) in total')

(c, s, r) = itertools.repeat(0, 3)
for chain in chains:
    if chain.start < cutoff.timestamp():
        break
    c += 1
    s += chain.chain
    r += chain.respect

print(f'{c} chain(s) totaling {s} hit(s) and {r} respect found after {cutoff.strftime("%c")}')
# Out:
# Found 882 chain(s) in total
# 149 chain(s) totaling 13645 hit(s) and 34567.81 respect found after Fri Oct 24 00:00:00 2025

# %%
url = f'{V1_BASE}/torn/?selections=stocks&key={KEY}'
try:
  jsh = Jsh.fetch(url)
except Exception as e:
  print(f'Failed to fetch "{url}": {e}')
  exit(1)
if not jsh.has('stocks'):
  print(f'No "stocks" in:\n{jsh.dumps()}')
  exit(1)

print('Ticker,Name,Benefit,Type,Frequency,Requirement,Price,Cost')
for v in jsh.getraw("stocks").values():
  s = Jsh.wrap(v)
  print(f'{s.acronym},"{s.name}","{s.benefit.description}",{s.benefit.type},{s.benefit.frequency},{s.benefit.requirement},{s.current_price},'
        f'{s.current_price*s.benefit.requirement}')
# Out:
# Ticker,Name,Benefit,Type,Frequency,Requirement,Price,Cost
# TSB,"Torn & Shanghai Banking","$50,000,000",active,31,3000000,1182.54,3547620000.0
# TCI,"Torn City Investments","a 10% bank interest bonus",passive,7,1500000,1194.2,1791300000.0
# SYS,"Syscore MFG","an Advanced firewall",passive,7,3000000,684.88,2054640000.0
# LAG,"Legal Authorities Group","1x Lawyer's Business Card",active,7,750000,452.95,339712500.0
# IOU,"Insured On Us","$12,000,000",active,31,3000000,179.05,537150000.0
# GRN,"Grain","$4,000,000",active,31,500000,305.53,152765000.0
# THS,"Torn City Health Service","1x Box of Medical Supplies",active,7,150000,383.31,57496500.0
# YAZ,"Yazoo","Free banner advertising",passive,7,1000000,55.04,55040000.0
# TCT,"The Torn City Times","$1,000,000",active,31,100000,316.29,31629000.000000004
# CNC,"Crude & Co","$80,000,000",active,31,7500000,889.62,6672150000.0
# MSG,"Messaging Inc.","Free classified advertising",passive,7,300000,282.67,84801000.0
# TMI,"TC Music Industries","$25,000,000",active,31,6000000,228.7,1372200000.0
# TCP,"TC Media Productions","a Company sales boost",passive,7,1000000,516.92,516919999.99999994
# IIL,"I Industries Ltd.","50% coding time reduction",passive,7,1000000,133.43,133430000.0
# FHG,"Feathery Hotels Group","1x Feathery Hotel Coupon",active,7,2000000,863.18,1726360000.0
# SYM,"Symbiotic Ltd.","1x Drug Pack",active,7,500000,688.55,344275000.0
# LSC,"Lucky Shot Casino","1x Lottery Voucher",active,7,500000,566.15,283075000.0
# PRN,"Performance Ribaldry","1x Erotic DVD",active,7,1000000,612.11,612110000.0
# EWM,"Eaglewood Mercenary","1x Box of Grenades",active,7,1000000,279.37,279370000.0
# TCM,"Torn City Motors","10% racing skill gain boost",passive,7,1000000,299.18,299180000.0
# ELT,"Empty Lunchbox Traders","10% home upgrade discount",passive,7,5000000,313.2,1566000000.0
# HRG,"Home Retail Group","1x Random Property",active,31,10000000,266.41,2664100000.0000005
# TGP,"Tell Group Plc.","a Company advertising boost",passive,7,2500000,145.83,364575000.00000006
# MUN,"Munster Beverage Corp.","1x Six-Pack of Energy Drink",active,7,5000000,554.57,2772850000.0000005
# WSU,"West Side University","a 10% education course time reduction",passive,7,1000000,109.49,109490000.0
# IST,"International School TC","Free education courses",passive,7,100000,525.28,52528000.0
# BAG,"Big Al's Gun Shop","1x Ammunition Pack",active,7,3000000,487.22,1461660000.0
# EVL,"Evil Ducks Candy Corp","1000 happiness",active,7,100000,652.11,65211000.0
# MCS,"Mc Smoogle Corp","100 energy",active,7,350000,801.9,280665000.0
# WLT,"Wind Lines Travel","Private jet access",passive,7,9000000,775.83,6982470000.0
# TCC,"Torn City Clothing","1x Clothing Cache",active,31,7500000,512.82,3846150000.0000005
# ASS,"Alcoholics Synonymous","1x Six-Pack of Alcohol",active,7,1000000,343.23,343230000.0
# CBD,"Herbal Releaf Co.","50 nerve",active,7,350000,405.74,142009000.0
# LOS,"Lo Squalo Waste","25% boost to mission credits and money earned",passive,7,7500000,109.93,824475000.0
# PTS,"PointLess","100 points",active,7,10000000,77.23,772300000.0
